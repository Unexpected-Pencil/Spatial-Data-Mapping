# %% [markdown]
# # 📊 04 - Data Input and Output
#
# Most of data science is about **loading data, exploring it, and saving results**.
# In this notebook you will learn:
# - Reading CSV files with Pandas
# - Inspecting DataFrames (`head`, `info`, `describe`)
# - Writing data back to CSV
# - Reading Excel files (if available)

# %% [markdown]
# ## 1. Reading CSV Files

# %%
import pandas as pd

# Create a small CSV for demo
data = """Name,Age,Score
Alice,23,90
Bob,25,85
Charlie,22,95
"""
with open("students.csv", "w") as f:
    f.write(data)

# Read CSV into DataFrame
df = pd.read_csv("students.csv")
df
# Out:
#       Name  Age  Score
# 0    Alice   23     90
# 1      Bob   25     85
# 2  Charlie   22     95

# %% [markdown]
# ✅ **Your Turn**: Create your own small CSV (3–5 rows) and read it into Pandas.

# %%
data = """Name,Year,Rating
Jaws,1975,4
Taxi Driver,1975,5
Dog Day Afternoon,1975,5
"""
with open("students.csv", "w") as f:
    f.write(data)

# Read CSV into DataFrame
df = pd.read_csv("students.csv")
df
# Out:
#                 Name  Year  Rating
# 0               Jaws  1975       4
# 1        Taxi Driver  1975       5
# 2  Dog Day Afternoon  1975       5

# %% [markdown]
# ## 2. Exploring DataFrames

# %%
# Look at the first rows
df.head()
# Out:
#                 Name  Year  Rating
# 0               Jaws  1975       4
# 1        Taxi Driver  1975       5
# 2  Dog Day Afternoon  1975       5

# %%
# Info about columns and data types
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      str
#  1   Year    3 non-null      int64
#  2   Rating  3 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 204.0 bytes

# %%
# Summary statistics
df.describe()
# Out:
#          Year    Rating
# count     3.0  3.000000
# mean   1975.0  4.666667
# std       0.0  0.577350
# min    1975.0  4.000000
# 25%    1975.0  4.500000
# 50%    1975.0  5.000000
# 75%    1975.0  5.000000
# max    1975.0  5.000000

# %%
df.head()
df.describe()
# Out:
#                 Name  Year  Rating
# 0               Jaws  1975       4
# 1        Taxi Driver  1975       5
# 2  Dog Day Afternoon  1975       5

# %% [markdown]
# ✅ **Your Turn**: Use `.head()` to preview your dataset and `.describe()` to see basic statistics.

# %% [markdown]
# ## 3. Writing CSV Files

# %%
# Save the DataFrame to a new CSV
df.to_csv("students_copy.csv", index=False)
# %ls *.csv

# %%
# Save the DataFrame to a new CSV
df.to_csv("my_data.csv", index=False)
# %ls *.csv
# Out:
# my_data.csv  students.csv

# %% [markdown]
# ✅ **Your Turn**: Save your DataFrame to a CSV file called `my_data.csv`.

# %% [markdown]
# ## 4. Reading Excel Files

# %%
# Optional: Requires 'openpyxl' installed
# Save to Excel
df.to_excel("students.xlsx", index=False)

# Read Excel file
pd.read_excel("students.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Optional: Requires 'openpyxl' installed
#       2 # Save to Excel
# ----> 3 df.to_excel("students.xlsx", index=False)
#       4
#       5 # Read Excel file
#       6 pd.read_excel("students.xlsx")
#
# File /workspaces/Spatial-Data-Mapping/.venv/lib/python3.12/site-packages/pandas/core/generic.py:2312, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs, autofilter)
#    2308             merge_cells=merge_cells,
#    2309             inf_rep=inf_rep,
#    2310             autofilter=autofilter,
#    2311         )
# -> 2312         formatter.write(
#    2313             excel_writer,
#    2314             sheet_name=sheet_name,
#    2315             startrow=startrow,
#
# File /workspaces/Spatial-Data-Mapping/.venv/lib/python3.12/site-packages/pandas/io/formats/excel.py:1003, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#    1001     need_save = False
#    1002 else:
# -> 1003     writer = ExcelWriter(
#    1004         writer,
#    1005         engine=engine,
#    1006         storage_options=storage_options,
#    1007         engine_kwargs=engine_kwargs,
#    1008     )
#    1009     need_save = True
#    1011 try:
#
# File /workspaces/Spatial-Data-Mapping/.venv/lib/python3.12/site-packages/pandas/io/excel/_openpyxl.py:58, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      45 def __init__(  # pyright: ignore[reportInconsistentConstructor]
#      46     self,
#      47     path: FilePath | WriteExcelBuffer | ExcelWriter,
#    (...)     56 ) -> None:
#      57     # Use the openpyxl module as the Excel writer.
# ---> 58     from openpyxl.workbook import Workbook
#      60     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      62     super().__init__(
#      63         path,
#      64         mode=mode,
#    (...)     67         engine_kwargs=engine_kwargs,
#      68     )
#
# ModuleNotFoundError: No module named 'openpyxl'

# %% [markdown]
# ✅ **Your Turn**: Try saving your dataset to Excel and reading it back (if supported in your environment).

# %% [markdown]
# ---
# ### Summary
# - `pd.read_csv` loads data into a DataFrame.
# - Use `.head()`, `.info()`, `.describe()` to explore quickly.
# - `df.to_csv` and `df.to_excel` save results.
# - Pandas makes file I/O simple and reliable.
