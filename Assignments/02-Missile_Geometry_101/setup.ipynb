# %%
import sys
print("Python executable:\n", sys.executable)

assert ".venv" in sys.executable, """
WRONG KERNEL.
Pick the kernel that ends with '(.venv)' (e.g., 4543 02 Missile Geo (.venv)).
"""
print("✅ Using .venv kernel")
# Out:
# Python executable:
#  /usr/local/python/3.12.1/bin/python
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[1], line 4
#       1 import sys
#       2 print("Python executable:\n", sys.executable)
#       3
# ----> 4 assert ".venv" in sys.executable, """
#       5 WRONG KERNEL.
#       6 Pick the kernel that ends with '(.venv)' (e.g., 4543 02 Missile Geo (.venv)).
#       7 """
#
# AssertionError:
# WRONG KERNEL.
# Pick the kernel that ends with '(.venv)' (e.g., 4543 02 Missile Geo (.venv)).

# %%
import folium
import shapefile
import shapely
import geojson
import numpy
import rich

print("✅ Imports OK")
print("pyshp (shapefile) from:", shapefile.__file__)
# Out:
# ✅ Imports OK
# pyshp (shapefile) from: /home/codespace/.local/lib/python3.12/site-packages/shapefile.py

# %%
m = folium.Map(location=[0, 0], zoom_start=2, tiles="OpenStreetMap")
