# %%
import wdo
from wdo.geo import haversine_km

# %load_ext autoreload
# %autoreload 2

print("Success! wdo is now a real library.")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Success! wdo is now a real library.
# <unknown>:1: SyntaxWarning: invalid escape sequence '\ '
# <unknown>:332: SyntaxWarning: invalid escape sequence '\ '
# <unknown>:1: SyntaxWarning: invalid escape sequence '\ '
# <unknown>:332: SyntaxWarning: invalid escape sequence '\ '
